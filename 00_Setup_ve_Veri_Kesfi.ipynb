# %% [markdown]
# <a href="https://colab.research.google.com/github/melike0019/GTZAN-Audio-Classification/blob/main/01_Setup_ve_Veri_Kesfi.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # ─── KURULUM (ilk çalıştırmada bir kez çalıştır) ───
# # Her kullanıcı kendi Drive'ında gtzan_project klasörü oluşturur.
# # Path değiştirmek istersen aşağıdaki base_path'i düzenle.

# %%
# !nvidia-smi

from google.colab import drive
drive.mount('/content/drive', force_remount=True)

import os
print("MyDrive erişimi:", os.path.exists('/content/drive/MyDrive'))
# Out:
# Sun May  3 20:27:23 2026
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 580.82.07              Driver Version: 580.82.07      CUDA Version: 13.0     |
# +-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  Tesla T4                       Off |   00000000:00:04.0 Off |                    0 |
# | N/A   38C    P8              9W /   70W |       0MiB /  15360MiB |      0%      Default |
# |                                         |                        |                  N/A |
# ...

# %%
import os

base_path = '/content/drive/MyDrive/gtzan_project'
folders = ['Data', 'Processed_Data', 'Models', 'Notebooks']

for folder in folders:
    folder_path = os.path.join(base_path, folder)
    os.makedirs(folder_path, exist_ok=True)

    placeholder = os.path.join(folder_path, '.gitkeep')
    with open(placeholder, 'w') as f:
        f.write('')
    print(f"✓ {folder_path}")

import subprocess
subprocess.run(['sync'])
print("\nSenkronizasyon tamamlandı.")
# Out:
# ✓ /content/drive/MyDrive/gtzan_project/Data
# ✓ /content/drive/MyDrive/gtzan_project/Processed_Data
# ✓ /content/drive/MyDrive/gtzan_project/Models
# ✓ /content/drive/MyDrive/gtzan_project/Notebooks
#
# Senkronizasyon tamamlandı.

# %%
# !pip install -q librosa torchaudio gradio seaborn

import torch, librosa, numpy as np
import matplotlib.pyplot as plt
print(f"PyTorch: {torch.__version__}")
print(f"librosa: {librosa.__version__}")
print(f"CUDA: {torch.cuda.is_available()}")
if torch.cuda.is_available():
    print(f"GPU: {torch.cuda.get_device_name(0)}")
# Out:
# PyTorch: 2.10.0+cu128
# librosa: 0.11.0
# CUDA: True
# GPU: Tesla T4
